# %%
import numpy as np

# %%
import pandas as pd

# %%
bus_details = pd.read_csv('bus_details.csv', delimiter=',')

# %%
destination = bus_details[bus_details["Destination"].str.contains("Saint", na=False)]

# %%
destination
# Out:
#             Bus  Bus_number         State  Line_id Line_short name  \
# 6     144718572   144718572       Inconnu      4.0              C4
# 32    186152520   186152520      En ligne      9.0               9
# 44    187553668   187553668      En ligne      2.0              C2
# 50    189154980   189154980      En ligne      2.0              C2
# 56    192557768   192557768      En ligne      2.0              C2
# 58    183750552   183750552      En ligne      2.0              C2
# 67    184751372   184751372      En ligne      3.0              C3
# 70    184951536   184951536  Haut-le-pied      3.0              C3
# 73    185552028   185552028       Inconnu      9.0               9
# 75    185952356   185952356      En ligne      9.0               9
# 91    189355144   189355144      En ligne      9.0               9
# 101   409335380   409335380      En ligne     52.0              52
# 108   191757112   191757112      En ligne      4.0              C4
# ...

# %%
max_rw = bus_details.iloc[bus_details['Line_id'].idxmax()]

# %%
max_rw
# Out:
# Bus                    412938332
# Bus_number             412938332
# State                   En ligne
# Line_id                      243
# Line_short name              243
# Meaning Code                   0
# Destination                 Pacé
# Contact information      48.1503
# Advanced / Delay        -1.72009
# Unnamed: 9                   324
# Name: 122, dtype: object
